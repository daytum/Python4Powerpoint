# %%
import type_curve_monthly
from pptx import Presentation
from pptx.util import Inches
from datetime import date
from pd2ppt import df_to_table
import matplotlib.pyplot as plt

from IPython.display import Markdown

# %% [markdown]
# # Daily Report

# %%
Markdown("## Generated on {:%m-%d-%Y}".format(date.today()))
# Out:
# ## Generated on 10-06-2020

# %% [markdown]
# # API = 33053040060000

# %%
p = type_curve_monthly.type_curve_plot(api='33053040060000')

# %%
type_curve_monthly.type_curve_summary_from_db(api='33053040060000')
# Out:
# <style  type="text/css" >
# </style><table id="T_b50ed0fe_07cd_11eb_85ed_02a174e6744a" ><thead>    <tr>        <th class="col_heading level0 col0" >IRR (%)</th>        <th class="col_heading level0 col1" >NPV10 (Million $)</th>        <th class="col_heading level0 col2" >ROI (yrs)</th>        <th class="col_heading level0 col3" >Payout (yrs)</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b50ed0fe_07cd_11eb_85ed_02a174e6744arow0_col0" class="data row0 col0" >1,841.44</td>
#                         <td id="T_b50ed0fe_07cd_11eb_85ed_02a174e6744arow0_col1" class="data row0 col1" >24.67</td>
#                         <td id="T_b50ed0fe_07cd_11eb_85ed_02a174e6744arow0_col2" class="data row0 col2" >10.16</td>
#                         <td id="T_b50ed0fe_07cd_11eb_85ed_02a174e6744arow0_col3" class="data row0 col3" >0.25</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # API = 05123421340000

# %%
p = type_curve_monthly.type_curve_plot(api='05123421340000')

# %%
type_curve_monthly.type_curve_summary_from_db(api='05123421340000')
# Out:
# <style  type="text/css" >
# </style><table id="T_b77abc4a_07cd_11eb_85ed_02a174e6744a" ><thead>    <tr>        <th class="col_heading level0 col0" >IRR (%)</th>        <th class="col_heading level0 col1" >NPV10 (Million $)</th>        <th class="col_heading level0 col2" >ROI (yrs)</th>        <th class="col_heading level0 col3" >Payout (yrs)</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b77abc4a_07cd_11eb_85ed_02a174e6744arow0_col0" class="data row0 col0" >540.58</td>
#                         <td id="T_b77abc4a_07cd_11eb_85ed_02a174e6744arow0_col1" class="data row0 col1" >10.96</td>
#                         <td id="T_b77abc4a_07cd_11eb_85ed_02a174e6744arow0_col2" class="data row0 col2" >4.78</td>
#                         <td id="T_b77abc4a_07cd_11eb_85ed_02a174e6744arow0_col3" class="data row0 col3" >0.42</td>
#             </tr>
#     </tbody></table>
